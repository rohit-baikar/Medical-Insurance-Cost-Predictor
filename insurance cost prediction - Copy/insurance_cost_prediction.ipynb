# %%
import pandas as pd

# %%
data = pd.read_csv('insurance.csv')
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1325   50    male  30.970         3     no  northwest  10600.54830
# 1326   18  female  31.920         0     no  northeast   2205.98080
# 1327   18  female  36.850         0     no  southeast   1629.83350
# 1328   21  female  25.800         0     no  southwest   2007.94500
# 1329   61  female  29.070         0    yes  northwest  29141.36030
#
# [1330 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (1329, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1329 entries, 0 to 1329
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1329 non-null   int64
#  1   sex       1329 non-null   object
#  2   bmi       1329 non-null   float64
#  3   children  1329 non-null   int64
#  4   smoker    1329 non-null   object
#  5   region    1329 non-null   object
#  6   charges   1329 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.1+ KB

# %%
data['age'].unique()
# Out:
# array([19, 18, 28, 33, 32, 31, 46, 37, 60, 25, 62, 23, 56, 27, 52, 30, 34,
#        59, 63, 55, 22, 26, 35, 24, 41, 38, 36, 21, 48, 40, 58, 53, 43, 64,
#        20, 61, 44, 57, 29, 45, 54, 49, 47, 51, 42, 50, 39], dtype=int64)

# %%
data['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data['bmi'].unique()
#data['bmi'] = round(data['bmi'],2)
# Out:
# array([27.9 , 33.77, 33.  , 22.7 , 28.88, 25.74, 33.44, 27.74, 29.83,
#        25.84, 26.22, 26.29, 34.4 , 39.82, 42.13, 24.6 , 30.78, 23.84,
#        40.3 , 35.3 , 36.01, 32.4 , 34.1 , 31.92, 28.02, 27.72, 23.08,
#        32.78, 17.39, 36.3 , 35.6 , 26.32, 28.6 , 28.31, 20.42, 32.97,
#        20.8 , 36.67, 39.9 , 26.6 , 36.63, 21.78, 30.8 , 37.05, 37.3 ,
#        38.66, 34.77, 24.53, 35.2 , 35.62, 33.63, 28.  , 34.43, 28.69,
#        36.96, 31.82, 31.68, 22.88, 37.34, 27.36, 33.66, 24.7 , 25.94,
#        22.42, 28.9 , 39.1 , 36.19, 23.98, 24.75, 28.5 , 28.1 , 32.01,
#        27.4 , 34.01, 29.59, 35.53, 39.8 , 26.88, 38.28, 37.62, 41.23,
#        34.8 , 22.9 , 31.16, 27.2 , 26.98, 39.49, 24.8 , 31.3 , 19.95,
#        19.3 , 31.6 , 25.46, 30.12, 29.92, 27.5 , 28.4 , 30.88, 27.94,
#        35.09, 29.7 , 35.72, 32.2 , 49.06, 27.17, 23.37, 37.1 , 23.75,
#        28.98, 31.35, 33.92, 28.78, 28.3 , 37.4 , 17.76, 34.7 , 26.5 ,
# ...

# %%
#data['bmi'].unique()

# %%
data['children'].unique()
# Out:
# array([0, 1, 3, 2, 5, 4], dtype=int64)

# %%
data['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
data
# Out:
#       age     sex    bmi  children smoker     region      charges
# 0      19  female  27.90         0    yes  southwest  16884.92400
# 1      18    male  33.77         1     no  southeast   1725.55230
# 2      28    male  33.00         3     no  southeast   4449.46200
# 3      33    male  22.70         0     no  northwest  21984.47061
# 4      32    male  28.88         0     no  northwest   3866.85520
# ...   ...     ...    ...       ...    ...        ...          ...
# 1325   50    male  30.97         3     no  northwest  10600.54830
# 1326   18  female  31.92         0     no  northeast   2205.98080
# 1327   18  female  36.85         0     no  southeast   1629.83350
# 1328   21  female  25.80         0     no  southwest   2007.94500
# 1329   61  female  29.07         0    yes  northwest  29141.36030
#
# [1329 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(data)

# %%
X = data["region"]
Y = data["charges"]

# %%
sns.set_style("darkgrid")
sns.scatterplot(x=X, y=Y, data=data)
plt.show()

# %%
sns.barplot(x=data['sex'], y=data['charges'],data=data,color="orange")
plt.show()

# %%
sns.barplot(x=data['sex'], y=data['charges'],data=data,color="orange", hue="smoker")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13176\4244438711.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:orange'` for the same effect.
#
#   sns.barplot(x=data['sex'], y=data['charges'],data=data,color="orange", hue="smoker")

# %%
sns.scatterplot(x=data['age'],y=data['charges'],data=data, color="red")
plt.show()

# %%
sns.scatterplot(x=data['bmi'],y=data['charges'],data=data,hue='sex',color='blue')
plt.show()

# %%
sns.scatterplot(x=data['bmi'],y=data['charges'],data=data,hue='smoker',color='blue')
plt.show()

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1329.000000  1329.000000  1329.000000   1329.000000
# mean     39.182092    30.628465     1.097065  13017.856433
# std      14.041192     6.090650     1.206308  11660.941136
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      26.000000    26.220000     0.000000   4719.736550
# 50%      39.000000    30.300000     1.000000   9301.893550
# 75%      51.000000    34.600000     2.000000  16297.846000
# max      64.000000    53.130000     5.000000  48970.247600

# %%
data
# Out:
#       age     sex    bmi  children smoker     region      charges
# 0      19  female  27.90         0    yes  southwest  16884.92400
# 1      18    male  33.77         1     no  southeast   1725.55230
# 2      28    male  33.00         3     no  southeast   4449.46200
# 3      33    male  22.70         0     no  northwest  21984.47061
# 4      32    male  28.88         0     no  northwest   3866.85520
# ...   ...     ...    ...       ...    ...        ...          ...
# 1325   50    male  30.97         3     no  northwest  10600.54830
# 1326   18  female  31.92         0     no  northeast   2205.98080
# 1327   18  female  36.85         0     no  southeast   1629.83350
# 1328   21  female  25.80         0     no  southwest   2007.94500
# 1329   61  female  29.07         0    yes  northwest  29141.36030
#
# [1329 rows x 7 columns]

# %%
data = data.drop(columns=['region'])
data
# Out:
#       age     sex    bmi  children smoker      charges
# 0      19  female  27.90         0    yes  16884.92400
# 1      18    male  33.77         1     no   1725.55230
# 2      28    male  33.00         3     no   4449.46200
# 3      33    male  22.70         0     no  21984.47061
# 4      32    male  28.88         0     no   3866.85520
# ...   ...     ...    ...       ...    ...          ...
# 1325   50    male  30.97         3     no  10600.54830
# 1326   18  female  31.92         0     no   2205.98080
# 1327   18  female  36.85         0     no   1629.83350
# 1328   21  female  25.80         0     no   2007.94500
# 1329   61  female  29.07         0    yes  29141.36030
#
# [1329 rows x 6 columns]

# %%
features = data.drop(columns = ['charges'])
features
# Out:
#       age     sex    bmi  children smoker
# 0      19  female  27.90         0    yes
# 1      18    male  33.77         1     no
# 2      28    male  33.00         3     no
# 3      33    male  22.70         0     no
# 4      32    male  28.88         0     no
# ...   ...     ...    ...       ...    ...
# 1325   50    male  30.97         3     no
# 1326   18  female  31.92         0     no
# 1327   18  female  36.85         0     no
# 1328   21  female  25.80         0     no
# 1329   61  female  29.07         0    yes
#
# [1329 rows x 5 columns]

# %%
target = data['charges']
target
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1325    10600.54830
# 1326     2205.98080
# 1327     1629.83350
# 1328     2007.94500
# 1329    29141.36030
# Name: charges, Length: 1329, dtype: float64

# %%
cfeatures = pd.get_dummies(features, drop_first=True)
cfeatures
# Out:
#       age    bmi  children  sex_male  smoker_yes
# 0      19  27.90         0     False        True
# 1      18  33.77         1      True       False
# 2      28  33.00         3      True       False
# 3      33  22.70         0      True       False
# 4      32  28.88         0      True       False
# ...   ...    ...       ...       ...         ...
# 1325   50  30.97         3      True       False
# 1326   18  31.92         0     False       False
# 1327   18  36.85         0     False       False
# 1328   21  25.80         0     False       False
# 1329   61  29.07         0     False        True
#
# [1329 rows x 5 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(cfeatures, target, test_size=0.2,random_state=37)

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(y_test, y_pred)
score
# Out:
# 0.811980783030682

# %%
age = int(input("enter age: "))
bmi = float(input("enter bmi: "))
children = int(input("enter no of children: "))
sex = int(input("enter 0 for female and 1 for male: "))
if sex == 0:
    d1 = [0]
else:
    d1 = [1]
smoker = int(input("enter 0 for no and 1 for yes: "))
if smoker == 0:
    d2 = [0]
else:
    d2 = [1]
d = [[age]+[bmi]+[children]+d1+d2]
res = model.predict(d)
print(res)
# Out:
# enter age:  55
# enter bmi:  26.8
# enter no of children:  1
# enter 0 for female and 1 for male:  0
# enter 0 for no and 1 for yes:  0
# [11489.51288824]
# C:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from pickle import *
f = open("lrmodel.pkl","wb")
dump(model,f)
f.close()
